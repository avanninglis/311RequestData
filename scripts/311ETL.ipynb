# %% [markdown]
# <a href="https://colab.research.google.com/github/avanninglis/311RequestData/blob/main/311ETL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install azure-storage-blob
# !pip install pyarrow
# Out:
# Collecting azure-storage-blob
#   Downloading azure_storage_blob-12.19.1-py3-none-any.whl (394 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.5/394.5 kB 7.3 MB/s eta 0:00:00
# Collecting azure-core<2.0.0,>=1.28.0 (from azure-storage-blob)
#   Downloading azure_core-1.30.1-py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.4/193.4 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (42.0.5)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (4.11.0)
# Collecting isodate>=0.6.1 (from azure-storage-blob)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.1.4->azure-storage-blob) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2024.2.2)
# Installing collected packages: isodate, azure-core, azure-storage-blob
# Successfully installed azure-core-1.30.1 azure-storage-blob-12.19.1 isodate-0.6.1
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (14.0.2)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from pyarrow) (1.25.2)

# %%
import pandas as pd
import numpy as np
import json
import requests
from io import StringIO
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
import datetime
import calendar

# %%
# Read Azure Blob Storage connection string from config.json
with open('config.json', 'r') as config_file:
    config = json.load(config_file)

# Get connection string from config
connection_string = config['connectionString']

# Create BlobServiceClient
blob_service_client = BlobServiceClient.from_connection_string(connection_string)
container_name = 'data'
blob_name = '311Data.csv'
download_file_path = '311DataFromBlob.csv'

blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)

with open(download_file_path, 'wb') as download_file:
    download_file.write(blob_client.download_blob().readall())

print(f"Blob {blob_name} has been downloaded")
# Out:
# Blob 311Data.csv has been downloaded

# %%
df = pd.read_csv('311DataFromBlob.csv')
Data_df = df.copy()
pd.set_option('display.max_columns', None)

Data_df.head(5)
# Out:
#    unique_key             created_date agency  \
# 0    60887125  2024-04-17T02:11:06.000    DOT
# 1    60890163  2024-04-17T01:51:34.000   NYPD
# 2    60883318  2024-04-17T01:51:32.000   NYPD
# 3    60886001  2024-04-17T01:51:00.000   NYPD
# 4    60886141  2024-04-17T01:50:53.000    DHS
#
#                        agency_name              complaint_type  \
# 0     Department of Transportation            Street Condition
# 1  New York City Police Department         Noise - Residential
# 2  New York City Police Department         Noise - Residential
# 3  New York City Police Department             Illegal Parking
# 4  Department of Homeless Services  Homeless Person Assistance
#
#                       descriptor  incident_zip         incident_address  \
# 0                        Pothole       11356.0                 7 AVENUE
# 1               Banging/Pounding           NaN                      NaN
# 2                   Loud Talking       11236.0    1570 EAST  102 STREET
# 3  Posted Parking Sign Violation       11367.0  67-45 KISSENA BOULEVARD
# 4                        Chronic       10019.0       200 WEST 52 STREET
#
#          street_name  cross_street_1    cross_street_2 address_type      city  \
# 0           7 AVENUE      122 STREET        123 STREET    BLOCKFACE    QUEENS
# 1                NaN             NaN               NaN          NaN       NaN
# 2   EAST  102 STREET  SEAVIEW AVENUE     SHORE PARKWAY      ADDRESS  BROOKLYN
# 3  KISSENA BOULEVARD       65 AVENUE  MELBOURNE AVENUE      ADDRESS  FLUSHING
# 4     WEST 52 STREET        7 AVENUE          BROADWAY      ADDRESS  NEW YORK
#
#   facility_type       status  \
# 0           NaN         Open
# 1           NaN  Unspecified
# 2           NaN  In Progress
# 3           NaN  In Progress
# 4           NaN     Assigned
#
#                               resolution_description  \
# 0  The Department of Transportation referred this...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  The Department of Homeless Services has sent a...
#
#   resolution_action_updated_date community_board      borough  \
# 0        2024-04-17T02:11:06.000       07 QUEENS       QUEENS
# 1        2024-04-17T02:19:37.000   0 Unspecified  Unspecified
# 2        2024-04-17T02:48:04.000     18 BROOKLYN     BROOKLYN
# 3                            NaN       08 QUEENS       QUEENS
# 4        2024-04-17T01:52:22.000    05 MANHATTAN    MANHATTAN
#
#   open_data_channel_type park_facility_name park_borough  \
# 0                UNKNOWN        Unspecified       QUEENS
# 1                 MOBILE        Unspecified  Unspecified
# 2                  PHONE        Unspecified     BROOKLYN
# 3                 MOBILE        Unspecified       QUEENS
# 4                 MOBILE        Unspecified    MANHATTAN
#
#                 location_type  x_coordinate_state_plane  \
# 0                         NaN                       NaN
# 1  Residential Building/House                 1000135.0
# 2  Residential Building/House                 1016286.0
# 3             Street/Sidewalk                 1035587.0
# 4             Street/Sidewalk                  989102.0
#
#    y_coordinate_state_plane   latitude  longitude  \
# 0                       NaN        NaN        NaN
# 1                  214358.0  40.755025 -73.942664
# 2                  170615.0  40.634917 -73.884576
# 3                  206861.0  40.734313 -73.814760
# 4                  217036.0  40.762389 -73.982485
#
#    :@computed_region_efsh_h5xi  :@computed_region_f5dn_yrer  \
# 0                          NaN                          NaN
# 1                      16858.0                         39.0
# 2                      13827.0                          5.0
# 3                      14509.0                         25.0
# 4                      12081.0                         11.0
#
#    :@computed_region_yeji_bk3q  :@computed_region_92fq_4b7q  \
# 0                          NaN                          NaN
# 1                          3.0                         33.0
# 2                          2.0                          8.0
# 3                          3.0                         24.0
# 4                          4.0                         51.0
#
#    :@computed_region_sbqj_enih  :@computed_region_7mpf_4k6g  \
# 0                          NaN                          NaN
# 1                         72.0                         72.0
# 2                         42.0                         42.0
# 3                         65.0                         65.0
# 4                         10.0                         10.0
#
#    location.latitude  location.longitude  \
# 0                NaN                 NaN
# 1          40.755025          -73.942664
# 2          40.634917          -73.884576
# 3          40.734313          -73.814760
# 4          40.762389          -73.982485
#
#                               location.human_address intersection_street_1  \
# 0                                                NaN                   NaN
# 1  {"address": "", "city": "", "state": "", "zip"...                   NaN
# 2  {"address": "", "city": "", "state": "", "zip"...        SEAVIEW AVENUE
# 3  {"address": "", "city": "", "state": "", "zip"...             65 AVENUE
# 4  {"address": "", "city": "", "state": "", "zip"...              7 AVENUE
#
#   intersection_street_2           landmark           bbl vehicle_type  \
# 0                   NaN                NaN           NaN          NaN
# 1                   NaN                NaN           NaN          NaN
# 2         SHORE PARKWAY   EAST  102 STREET  3.083290e+09          NaN
# 3      MELBOURNE AVENUE  KISSENA BOULEVARD  4.067920e+09          NaN
# 4              BROADWAY   WEST   52 STREET  1.010230e+09          NaN
#
#   closed_date due_date bridge_highway_name bridge_highway_direction road_ramp  \
# 0         NaN      NaN                 NaN                      NaN       NaN
# 1         NaN      NaN                 NaN                      NaN       NaN
# 2         NaN      NaN                 NaN                      NaN       NaN
# 3         NaN      NaN                 NaN                      NaN       NaN
# 4         NaN      NaN                 NaN                      NaN       NaN
#
#   bridge_highway_segment taxi_pick_up_location taxi_company_borough
# 0                    NaN                   NaN                  NaN
# 1                    NaN                   NaN                  NaN
# 2                    NaN                   NaN                  NaN
# 3                    NaN                   NaN                  NaN
# 4                    NaN                   NaN                  NaN

# %%
# ['unique_key', 'created_date', 'agency', 'agency_name', 'complaint_type',
#        'descriptor', 'incident_zip', 'incident_address', 'street_name',
#        'cross_street_1', 'cross_street_2', 'address_type', 'city',
#        'facility_type', 'status', 'resolution_description',
#        'resolution_action_updated_date', 'community_board', 'borough',
#        'open_data_channel_type', 'park_facility_name', 'park_borough',
#        'location_type', 'x_coordinate_state_plane', 'y_coordinate_state_plane',
#        'latitude', 'longitude', ':@computed_region_efsh_h5xi',
#        ':@computed_region_f5dn_yrer', ':@computed_region_yeji_bk3q',
#        ':@computed_region_92fq_4b7q', ':@computed_region_sbqj_enih',
#        ':@computed_region_7mpf_4k6g', 'location.latitude',
#        'location.longitude', 'location.human_address', 'intersection_street_1',
#        'intersection_street_2', 'landmark', 'bbl', 'vehicle_type',
#        'closed_date', 'due_date', 'bridge_highway_name',
#        'bridge_highway_direction', 'road_ramp', 'bridge_highway_segment',
#        'taxi_pick_up_location', 'taxi_company_borough'],
#       dtype='object')

# %%
# Removing NaN
Data_df.dropna(subset=['unique_key', 'incident_zip'], inplace=True)
#formatting columns
Data_df['created_date'] = pd.to_datetime(Data_df['created_date'])
Data_df['closed_date'] = pd.to_datetime(Data_df['closed_date'])
Data_df['due_date'] = pd.to_datetime(Data_df['due_date'])
Data_df['resolution_action_updated_date'] = pd.to_datetime(Data_df['resolution_action_updated_date'])
Data_df['incident_zip'] = Data_df['incident_zip'].astype('Int64')

Data_df.drop(columns=['facility_type',
                      'vehicle_type',
                      'bridge_highway_name',
                      'bridge_highway_direction',
                      'location.human_address',
                      'landmark',
                      'bbl',
                      'road_ramp',
                      'bridge_highway_segment',
                      'taxi_pick_up_location',
                      'taxi_company_borough',
                      'location.latitude',
                      'location.longitude',
                      ':@computed_region_efsh_h5xi',
                      'x_coordinate_state_plane',
                      'y_coordinate_state_plane',
                      ':@computed_region_f5dn_yrer',
                      ':@computed_region_yeji_bk3q',
                      ':@computed_region_92fq_4b7q',
                      ':@computed_region_sbqj_enih',
                      ':@computed_region_7mpf_4k6g',
                      'resolution_description'], inplace=True)

pd.set_option('display.max_columns', None) #to see all the columns
Data_df.head()
# Out:
#    unique_key        created_date agency                      agency_name  \
# 0    60887125 2024-04-17 02:11:06    DOT     Department of Transportation
# 2    60883318 2024-04-17 01:51:32   NYPD  New York City Police Department
# 3    60886001 2024-04-17 01:51:00   NYPD  New York City Police Department
# 4    60886141 2024-04-17 01:50:53    DHS  Department of Homeless Services
# 5    60889980 2024-04-17 01:50:38   NYPD  New York City Police Department
#
#                complaint_type                     descriptor  incident_zip  \
# 0            Street Condition                        Pothole         11356
# 2         Noise - Residential                   Loud Talking         11236
# 3             Illegal Parking  Posted Parking Sign Violation         11367
# 4  Homeless Person Assistance                        Chronic         10019
# 5            Blocked Driveway                      No Access         11379
#
#           incident_address        street_name             cross_street_1  \
# 0                 7 AVENUE           7 AVENUE                 122 STREET
# 2    1570 EAST  102 STREET   EAST  102 STREET             SEAVIEW AVENUE
# 3  67-45 KISSENA BOULEVARD  KISSENA BOULEVARD                  65 AVENUE
# 4       200 WEST 52 STREET     WEST 52 STREET                   7 AVENUE
# 5          57-59 78 STREET          78 STREET  QUEENS MIDTOWN EXPRESSWAY
#
#      cross_street_2 address_type            city       status  \
# 0        123 STREET    BLOCKFACE          QUEENS         Open
# 2     SHORE PARKWAY      ADDRESS        BROOKLYN  In Progress
# 3  MELBOURNE AVENUE      ADDRESS        FLUSHING  In Progress
# 4          BROADWAY      ADDRESS        NEW YORK     Assigned
# 5           57 ROAD      ADDRESS  MIDDLE VILLAGE  In Progress
#
#   resolution_action_updated_date community_board    borough  \
# 0            2024-04-17 02:11:06       07 QUEENS     QUEENS
# 2            2024-04-17 02:48:04     18 BROOKLYN   BROOKLYN
# 3                            NaT       08 QUEENS     QUEENS
# 4            2024-04-17 01:52:22    05 MANHATTAN  MANHATTAN
# 5                            NaT       05 QUEENS     QUEENS
#
#   open_data_channel_type park_facility_name park_borough  \
# 0                UNKNOWN        Unspecified       QUEENS
# 2                  PHONE        Unspecified     BROOKLYN
# 3                 MOBILE        Unspecified       QUEENS
# 4                 MOBILE        Unspecified    MANHATTAN
# 5                 ONLINE        Unspecified       QUEENS
#
#                 location_type   latitude  longitude  \
# 0                         NaN        NaN        NaN
# 2  Residential Building/House  40.634917 -73.884576
# 3             Street/Sidewalk  40.734313 -73.814760
# 4             Street/Sidewalk  40.762389 -73.982485
# 5             Street/Sidewalk  40.727503 -73.883420
#
#        intersection_street_1 intersection_street_2 closed_date due_date
# 0                        NaN                   NaN         NaT      NaT
# 2             SEAVIEW AVENUE         SHORE PARKWAY         NaT      NaT
# 3                  65 AVENUE      MELBOURNE AVENUE         NaT      NaT
# 4                   7 AVENUE              BROADWAY         NaT      NaT
# 5  QUEENS MIDTOWN EXPRESSWAY               57 ROAD         NaT      NaT

# %%
# Getting unique values of 'agency_name' and assign numeric IDs
agency_type_unique = Data_df['agency_name'].unique()
agencyType_mapping = {agency_name: idx for idx, agency_name in enumerate(agency_type_unique, start=1)}

# Create a DataFrame for agency types with their numeric IDs
AgencyType_id = pd.DataFrame(columns=['agencyType_id', 'agency_name'])

# Add data to the DataFrame
AgencyType_id['agency_name'] = agencyType_mapping.keys()
AgencyType_id['agencyType_id'] = AgencyType_id['agency_name'].map(agencyType_mapping)

# Map agency names to their corresponding IDs
Data_df['agencyType_id'] = Data_df['agency_name'].map(AgencyType_id.set_index('agency_name')['agencyType_id'])

# Display the DataFrame with the newly added 'agencyType_id' column
AgencyType_id
# Out:
#     agencyType_id                                        agency_name
# 0               1                       Department of Transportation
# 1               2                    New York City Police Department
# 2               3                    Department of Homeless Services
# 3               4            Department of Health and Mental Hygiene
# 4               5                           Department of Sanitation
# 5               6                 Department of Parks and Recreation
# 6               7       Department of Consumer and Worker Protection
# 7               8  Department of Housing Preservation and Develop...
# 8               9             Department of Environmental Protection
# 9              10                   Economic Development Corporation
# 10             11                      Taxi and Limousine Commission
# 11             12                            Department of Buildings
# 12             13                            Department of Education

# %%
location_type_unique = Data_df['location_type'].unique()
locationType_mapping = {location_type: idx for idx, location_type in enumerate(location_type_unique, start=1)}

# Create a DataFrame for complaint types with their numeric IDs
LocationType_id = pd.DataFrame(columns=['locationType_id', 'locationType'])

# Add data to the DataFrame
LocationType_id['locationType_id'] = locationType_mapping.values()
LocationType_id['locationType'] = locationType_mapping.keys()
Data_df['locationType_id'] = Data_df['location_type'].map(locationType_mapping)

LocationType_id
# Out:
#     locationType_id                   locationType
# 0                 1                            NaN
# 1                 2     Residential Building/House
# 2                 3                Street/Sidewalk
# 3                 4   3+ Family Apartment Building
# 4                 5                            Lot
# 5                 6            Club/Bar/Restaurant
# 6                 7                         Street
# 7                 8                Park/Playground
# 8                 9                       Sidewalk
# 9                10               Store/Commercial
# 10               11                      Mixed Use
# 11               12        3+ Family Apt. Building
# 12               13     Restaurant/Bar/Deli/Bakery
# 13               14                       Business
# 14               15            Commercial Building
# 15               16                          Other
# 16               17           RESIDENTIAL BUILDING
# 17               18           Residential Building
# 18               19                           Park
# 19               20                  Above Address
# 20               21              Construction Site
# 21               22            1-2 Family Dwelling
# 22               23             Mobile Food Vendor
# 23               24          Other (Explain Below)
# 24               25   3+ Family Mixed Use Building
# 25               26                           Yard
# 26               27               House of Worship
# 27               28                      Comercial
# 28               29                Vacant Building
# 29               30               Bus Stop Shelter
# 30               31               Private Property
# 31               32           Public/Unfenced Area
# 32               33                         School
# 33               34       Traffic Island or Median
# 34               35                           Taxi
# 35               36                Street/Curbside
# 36               37             Parking Lot/Garage
# 37               38                    Residential
# 38               39           Permanent Food Stand
# 39               40                 Private School
# 40               41                 Loft Residence
# 41               42                     Vacant Lot
# 42               43                          Alley
# 43               44                      Apartment
# 44               45  1-2 Family Mixed Use Building
# 45               46               Day Care/Nursery
# 46               47                         Gutter
# 47               48   Food Establishment or Vendor
# 48               49                  Speed Reducer
# 49               50                        Highway
# 50               51                      Residence
# 51               52                           Pool
# 52               53                          Sauna
# 53               54                           Curb
# 54               55                House and Store
# 55               56                  Public Garden
# 56               57                         Bridge
# 57               58          Kennel/Animal Shelter

# %%
unique_locations = Data_df[['incident_zip', 'incident_address', 'street_name', 'cross_street_1', 'cross_street_2',
                            'city', 'borough', 'location_type', 'latitude', 'longitude','intersection_street_1','intersection_street_2']].drop_duplicates()


# Generating location IDs
location_ids = range(1, len(unique_locations) + 1)
# Creating the Location Dimensional Table
Location_id = pd.DataFrame({
    'location_id': location_ids,
    'locationType_id': unique_locations['location_type'].map(locationType_mapping),  # Using locationType_id as the second column
    'incident_zip': unique_locations['incident_zip'],
    'incident_address': unique_locations['incident_address'],
    'street_name': unique_locations['street_name'],
    'cross_street_1': unique_locations['cross_street_1'],
    'cross_street_2': unique_locations['cross_street_2'],
    'city': unique_locations['city'],
    'borough': unique_locations['borough'],
    'latitude': unique_locations['latitude'],
    'longitude': unique_locations['longitude'],
    'intersection_street_1':unique_locations['intersection_street_1'],
    'intersection_street_2':unique_locations['intersection_street_2']})

# Displaying the Location Dimensional Table
Location_id
# Out:
#       location_id  locationType_id  incident_zip  \
# 0               1                1         11356
# 2               2                2         11236
# 3               3                3         11367
# 4               4                3         10019
# 5               5                3         11379
# ...           ...              ...           ...
# 9991         7444                3         11231
# 9992         7445                3         11220
# 9993         7446                3         10467
# 9995         7447                6         11236
# 9998         7448                2         11239
#
#                    incident_address                 street_name  \
# 0                          7 AVENUE                    7 AVENUE
# 2             1570 EAST  102 STREET            EAST  102 STREET
# 3           67-45 KISSENA BOULEVARD           KISSENA BOULEVARD
# 4                200 WEST 52 STREET              WEST 52 STREET
# 5                   57-59 78 STREET                   78 STREET
# ...                             ...                         ...
# 9991                7 COFFEY STREET               COFFEY STREET
# 9992                  372 49 STREET                   49 STREET
# 9993  45 EAST MOSHOLU PARKWAY NORTH  EAST MOSHOLU PARKWAY NORTH
# 9995              1663 RALPH AVENUE                RALPH AVENUE
# 9998                200 BETHEL LOOP                 BETHEL LOOP
#
#                  cross_street_1    cross_street_2            city    borough  \
# 0                    122 STREET        123 STREET          QUEENS     QUEENS
# 2                SEAVIEW AVENUE     SHORE PARKWAY        BROOKLYN   BROOKLYN
# 3                     65 AVENUE  MELBOURNE AVENUE        FLUSHING     QUEENS
# 4                      7 AVENUE          BROADWAY        NEW YORK  MANHATTAN
# 5     QUEENS MIDTOWN EXPRESSWAY           57 ROAD  MIDDLE VILLAGE     QUEENS
# ...                         ...               ...             ...        ...
# 9991              OTSEGO STREET     DWIGHT STREET        BROOKLYN   BROOKLYN
# 9992                   3 AVENUE          4 AVENUE        BROOKLYN   BROOKLYN
# 9993              JEROME AVENUE    KOSSUTH AVENUE           BRONX      BRONX
# 9995           EAST   77 STREET  EAST   76 STREET        BROOKLYN   BROOKLYN
# 9998                       BEND   VANDALIA AVENUE        BROOKLYN   BROOKLYN
#
#        latitude  longitude      intersection_street_1 intersection_street_2
# 0           NaN        NaN                        NaN                   NaN
# 2     40.634917 -73.884576             SEAVIEW AVENUE         SHORE PARKWAY
# 3     40.734313 -73.814760                  65 AVENUE      MELBOURNE AVENUE
# 4     40.762389 -73.982485                   7 AVENUE              BROADWAY
# 5     40.727503 -73.883420  QUEENS MIDTOWN EXPRESSWAY               57 ROAD
# ...         ...        ...                        ...                   ...
# 9991  40.673830 -74.010617              OTSEGO STREET         DWIGHT STREET
# 9992  40.647414 -74.012652                   3 AVENUE              4 AVENUE
# 9993  40.879437 -73.883230              JEROME AVENUE        KOSSUTH AVENUE
# 9995  40.636275 -73.919037           EAST   77 STREET      EAST   76 STREET
# 9998  40.652097 -73.881620                       BEND       VANDALIA AVENUE
#
# [7448 rows x 13 columns]

# %%
# Assuming 'Data_df' is your DataFrame containing the data

# # Selecting unique locations based on specific columns
# unique_locations = Data_df[['incident_zip', 'incident_address', 'street_name', 'cross_street_1', 'cross_street_2',
#                             'city', 'borough', 'location_type', 'latitude', 'longitude','intersection_street_1','intersection_street_2']].drop_duplicates()

# # Generating location IDs
# location_ids = range(1, len(unique_locations) + 1)

# # Creating the Location Dimensional Table
# Location_id = pd.DataFrame({
#     'location_id': location_ids,
#     'incident_zip': unique_locations['incident_zip'],
#     'incident_address': unique_locations['incident_address'],
#     'street_name': unique_locations['street_name'],
#     'cross_street_1': unique_locations['cross_street_1'],
#     'cross_street_2': unique_locations['cross_street_2'],
#     'city': unique_locations['city'],
#     'borough': unique_locations['borough'],
#     'latitude': unique_locations['latitude'],
#     'longitude': unique_locations['longitude'],
#     'intersection_street_1': unique_locations['intersection_street_1'],
#     'intersection_street_2': unique_locations['intersection_street_2']
# })

# # Mapping location IDs to 'Data_df' based on incident_address
# Data_df = Data_df.merge(Location_id[['location_id', 'incident_address']], on='incident_address', how='left')

# # Displaying the Location Dimensional Table
# Location_id

# %%
# Create a dictionary mapping incident addresses to location IDs
address_to_location_id = Location_id.set_index('incident_address')['location_id'].to_dict()

# Map location IDs to Data_df based on incident address
Data_df['location_id'] = Data_df['incident_address'].map(address_to_location_id)
Data_df
# Out:
#       unique_key        created_date agency                      agency_name  \
# 0       60887125 2024-04-17 02:11:06    DOT     Department of Transportation
# 2       60883318 2024-04-17 01:51:32   NYPD  New York City Police Department
# 3       60886001 2024-04-17 01:51:00   NYPD  New York City Police Department
# 4       60886141 2024-04-17 01:50:53    DHS  Department of Homeless Services
# 5       60889980 2024-04-17 01:50:38   NYPD  New York City Police Department
# ...          ...                 ...    ...                              ...
# 9995    60882623 2024-04-16 04:34:42   NYPD  New York City Police Department
# 9996    60890206 2024-04-16 04:32:58   NYPD  New York City Police Department
# 9997    60886084 2024-04-16 04:32:15   NYPD  New York City Police Department
# 9998    60884514 2024-04-16 04:31:55   NYPD  New York City Police Department
# 9999    60887481 2024-04-16 04:31:55   NYPD  New York City Police Department
#
#                   complaint_type                     descriptor  incident_zip  \
# 0               Street Condition                        Pothole         11356
# 2            Noise - Residential                   Loud Talking         11236
# 3                Illegal Parking  Posted Parking Sign Violation         11367
# 4     Homeless Person Assistance                        Chronic         10019
# 5               Blocked Driveway                      No Access         11379
# ...                          ...                            ...           ...
# 9995          Noise - Commercial               Loud Music/Party         11236
# 9996             Illegal Parking    Parking Permit Improper Use         11205
# 9997             Illegal Parking    Parking Permit Improper Use         11101
# 9998                Animal-Abuse      Other (complaint details)         11239
# 9999             Illegal Parking    Parking Permit Improper Use         11222
#
#              incident_address        street_name             cross_street_1  \
# 0                    7 AVENUE           7 AVENUE                 122 STREET
# 2       1570 EAST  102 STREET   EAST  102 STREET             SEAVIEW AVENUE
# 3     67-45 KISSENA BOULEVARD  KISSENA BOULEVARD                  65 AVENUE
# 4          200 WEST 52 STREET     WEST 52 STREET                   7 AVENUE
# 5             57-59 78 STREET          78 STREET  QUEENS MIDTOWN EXPRESSWAY
# ...                       ...                ...                        ...
# 9995        1663 RALPH AVENUE       RALPH AVENUE           EAST   77 STREET
# 9996            2 PARK AVENUE        PARK AVENUE                NAVY STREET
# 9997           5-47 50 AVENUE          50 AVENUE                   5 STREET
# 9998          200 BETHEL LOOP        BETHEL LOOP                       BEND
# 9999      100 MESEROLE AVENUE    MESEROLE AVENUE             LORIMER STREET
#
#         cross_street_2 address_type              city       status  \
# 0           123 STREET    BLOCKFACE            QUEENS         Open
# 2        SHORE PARKWAY      ADDRESS          BROOKLYN  In Progress
# 3     MELBOURNE AVENUE      ADDRESS          FLUSHING  In Progress
# 4             BROADWAY      ADDRESS          NEW YORK     Assigned
# 5              57 ROAD      ADDRESS    MIDDLE VILLAGE  In Progress
# ...                ...          ...               ...          ...
# 9995  EAST   76 STREET      ADDRESS          BROOKLYN       Closed
# 9996     MONUMENT WALK      ADDRESS          BROOKLYN       Closed
# 9997  VERNON BOULEVARD      ADDRESS  LONG ISLAND CITY       Closed
# 9998   VANDALIA AVENUE      ADDRESS          BROOKLYN       Closed
# 9999  MANHATTAN AVENUE      ADDRESS          BROOKLYN       Closed
#
#      resolution_action_updated_date community_board    borough  \
# 0               2024-04-17 02:11:06       07 QUEENS     QUEENS
# 2               2024-04-17 02:48:04     18 BROOKLYN   BROOKLYN
# 3                               NaT       08 QUEENS     QUEENS
# 4               2024-04-17 01:52:22    05 MANHATTAN  MANHATTAN
# 5                               NaT       05 QUEENS     QUEENS
# ...                             ...             ...        ...
# 9995            2024-04-16 05:24:19     18 BROOKLYN   BROOKLYN
# 9996            2024-04-16 05:18:51     02 BROOKLYN   BROOKLYN
# 9997            2024-04-16 04:33:58       02 QUEENS     QUEENS
# 9998            2024-04-16 06:15:30     05 BROOKLYN   BROOKLYN
# 9999            2024-04-16 04:37:06     01 BROOKLYN   BROOKLYN
#
#      open_data_channel_type park_facility_name park_borough  \
# 0                   UNKNOWN        Unspecified       QUEENS
# 2                     PHONE        Unspecified     BROOKLYN
# 3                    MOBILE        Unspecified       QUEENS
# 4                    MOBILE        Unspecified    MANHATTAN
# 5                    ONLINE        Unspecified       QUEENS
# ...                     ...                ...          ...
# 9995                 ONLINE        Unspecified     BROOKLYN
# 9996                 MOBILE        Unspecified     BROOKLYN
# 9997                 MOBILE        Unspecified       QUEENS
# 9998                  PHONE        Unspecified     BROOKLYN
# 9999                 MOBILE        Unspecified     BROOKLYN
#
#                    location_type   latitude  longitude  \
# 0                            NaN        NaN        NaN
# 2     Residential Building/House  40.634917 -73.884576
# 3                Street/Sidewalk  40.734313 -73.814760
# 4                Street/Sidewalk  40.762389 -73.982485
# 5                Street/Sidewalk  40.727503 -73.883420
# ...                          ...        ...        ...
# 9995         Club/Bar/Restaurant  40.636275 -73.919037
# 9996             Street/Sidewalk  40.696188 -73.979920
# 9997             Street/Sidewalk  40.743116 -73.956067
# 9998  Residential Building/House  40.652097 -73.881620
# 9999             Street/Sidewalk  40.726992 -73.952982
#
#           intersection_street_1 intersection_street_2         closed_date  \
# 0                           NaN                   NaN                 NaT
# 2                SEAVIEW AVENUE         SHORE PARKWAY                 NaT
# 3                     65 AVENUE      MELBOURNE AVENUE                 NaT
# 4                      7 AVENUE              BROADWAY                 NaT
# 5     QUEENS MIDTOWN EXPRESSWAY               57 ROAD                 NaT
# ...                         ...                   ...                 ...
# 9995           EAST   77 STREET      EAST   76 STREET 2024-04-16 05:24:16
# 9996                NAVY STREET         MONUMENT WALK 2024-04-16 05:18:48
# 9997                   5 STREET      VERNON BOULEVARD 2024-04-16 04:33:53
# 9998                       BEND       VANDALIA AVENUE 2024-04-16 06:15:25
# 9999             LORIMER STREET      MANHATTAN AVENUE 2024-04-16 04:37:02
#
#      due_date  agencyType_id  locationType_id  location_id
# 0         NaT              1                1         6555
# 2         NaT              2                2            2
# 3         NaT              2                3            3
# 4         NaT              3                3            4
# 5         NaT              2                3            5
# ...       ...            ...              ...          ...
# 9995      NaT              2                6         7447
# 9996      NaT              2                3         4378
# 9997      NaT              2                3         4381
# 9998      NaT              2                2         7448
# 9999      NaT              2                3         4368
#
# [9906 rows x 30 columns]

# %%
# Getting unique values of 'complaint_type' and assign numeric IDs
complaint_type_unique = Data_df['complaint_type'].unique()
complaintType_mapping = {complaint_type: idx for idx, complaint_type in enumerate(complaint_type_unique, start=1)}

# Create DataFrame for complaint types with their numeric IDs
ComplaintType_id = pd.DataFrame(columns=['complaintType_id', 'complaintType'])
ComplaintType_id['complaintType_id'] = complaintType_mapping.values()
ComplaintType_id['complaintType'] = complaintType_mapping.keys()
# Add data to the DataFrame
Data_df['complaintType_id'] = Data_df['complaint_type'].map(complaintType_mapping)
ComplaintType_id
# Out:
#      complaintType_id                complaintType
# 0                   1             Street Condition
# 1                   2          Noise - Residential
# 2                   3              Illegal Parking
# 3                   4   Homeless Person Assistance
# 4                   5             Blocked Driveway
# ..                ...                          ...
# 120               121            Derelict Vehicles
# 121               122          Wood Pile Remaining
# 122               123  Animal Facility - No Permit
# 123               124     Noise - House of Worship
# 124               125      For Hire Vehicle Report
#
# [125 rows x 2 columns]

# %%
# Getting unique values of 'status' and assign numeric IDs
status_type_unique = Data_df['status'].unique()
statusType_mapping = {status_type: idx for idx, status_type in enumerate(status_type_unique, start=1)}

# Create a DataFrame for complaint types with their numeric IDs
StatusType_id = pd.DataFrame(columns=['statusType_id', 'statusType'])

# Add data to the DataFrame
StatusType_id['statusType_id'] = statusType_mapping.values()
StatusType_id['statusType'] = statusType_mapping.keys()
Data_df['statusType_id'] = Data_df['status'].map(statusType_mapping)
StatusType_id
# Out:
#    statusType_id   statusType
# 0              1         Open
# 1              2  In Progress
# 2              3     Assigned
# 3              4       Closed
# 4              5      Started
# 5              6  Unspecified
# 6              7      Pending

# %%
park_facility = Data_df['park_facility_name'].unique()
park_facility_mapping = {park_facility: idx for idx, park_facility in enumerate(park_facility, start=1)}


Park_facility_id = pd.DataFrame(columns=['park_facility_id', 'park_facility_name'])

# Add data to the DataFrame
Park_facility_id['park_facility_id'] = park_facility_mapping.values()
Park_facility_id['park_facility_name'] = park_facility_mapping.keys()
Data_df['park_facility_id'] = Data_df['park_facility_name'].map(park_facility_mapping )
Park_facility_id
# Out:
#     park_facility_id                                 park_facility_name
# 0                  1                                        Unspecified
# 1                  2                             Washington Square Park
# 2                  3                                                NaN
# 3                  4                        William Sheridan Playground
# 4                  5                                   Ferry Point Park
# 5                  6                              Bill Brown Playground
# 6                  7                                  Gorman Playground
# 7                  8                                    Alley Pond Park
# 8                  9                                   Franz Sigel Park
# 9                 10                                   Fort Totten Park
# 10                11                                 Francis Lewis Park
# 11                12                              Whitestone Playground
# 12                13                        Hoover - Manton Playgrounds
# 13                14                               Washington Hall Park
# 14                15                                   Fort Greene Park
# 15                16                                  Union Square Park
# 16                17                                  Battery Park City
# 17                18                                      Friends Field
# 18                19                              Kissena Corridor Park
# 19                20                                     Underwood Park
# 20                21                                  Montefiore Square
# 21                22  Success Academy Charter School - Bergen Beach ...
# 22                23                             J.H.S. 078 Roy H. Mann
# 23                24                                 Van Cortlandt Park
# 24                25                                 Pugsley Creek Park
# 25                26                                     Soundview Park
# 26                27                                         Bronx Park
# 27                28                                        Sunset Park
# 28                29                 New Heights Academy Charter School
# 29                30                                Juniper Valley Park
# 30                31                             Highland Park (Queens)
# 31                32                       Flushing Meadows Corona Park
# 32                33                              Gouverneur Playground
# 33                34                                 Century Playground
# 34                35                                    McCarthy Square
# 35                36                                     Yu Suen Garden
# 36                37                                 Clawson Playground
# 37                38                                Williamsbridge Oval
# 38                39                     P.S. 115 Daniel Mucatel School
# 39                40                               Rappaport Playground
# 40                41                               Garibaldi Playground
# 41                42                                 Coleman Playground
# 42                43                             Remsen Family Cemetery
# 43                44                               Joseph C. Sauer Park
# 44                45                           I.S. 227 Louis Armstrong
# 45                46                               De Witt Clinton Park

# %%
# Getting unique values of 'status' and assign numeric IDs
community_board_unique = Data_df['community_board'].unique()
community_board_mapping = {community_board: idx for idx, community_board in enumerate(community_board_unique, start=1)}

# Create a DataFrame for complaint types with their numeric IDs
Community_board_id = pd.DataFrame(columns=['community_board_id', 'community_board'])

# Add data to the DataFrame
Community_board_id['community_board_id'] = community_board_mapping.values()
Community_board_id['community_board'] = community_board_mapping.keys()
Data_df['community_board_id'] = Data_df['community_board'].map(community_board_mapping)
Community_board_id
# Out:
#     community_board_id            community_board
# 0                    1                  07 QUEENS
# 1                    2                18 BROOKLYN
# 2                    3                  08 QUEENS
# 3                    4               05 MANHATTAN
# 4                    5                  05 QUEENS
# ..                 ...                        ...
# 70                  71              0 Unspecified
# 71                  72                  83 QUEENS
# 72                  73  Unspecified STATEN ISLAND
# 73                  74           95 STATEN ISLAND
# 74                  75                   27 BRONX
#
# [75 rows x 2 columns]

# %%
# Getting unique values of 'status' and assign numeric IDs
channel_unique = Data_df['open_data_channel_type'].unique()
channel_mapping = {open_data_channel_type: idx for idx, open_data_channel_type in enumerate(channel_unique, start=1)}

# Create a DataFrame for complaint types with their numeric IDs
Channel_id = pd.DataFrame(columns=['channel_id', 'channelType'])

# Add data to the DataFrame
Channel_id['channel_id'] = channel_mapping.values()
Channel_id['channelType'] = channel_mapping.keys()

Data_df['channel_id'] = Data_df['open_data_channel_type'].map(channel_mapping)
Channel_id
# Out:
#    channel_id channelType
# 0           1     UNKNOWN
# 1           2       PHONE
# 2           3      MOBILE
# 3           4      ONLINE

# %%
Data_df['created_date_id'] = pd.to_datetime(Data_df['created_date']).dt.strftime('%Y%m%d%H%M%S')
Data_df['closed_date_id'] = pd.to_datetime(Data_df['closed_date']).dt.strftime('%Y%m%d%H%M%S')
Data_df['due_date_id'] = pd.to_datetime(Data_df['due_date']).dt.strftime('%Y%m%d%H%M%S')
Data_df['updated_date_id'] = pd.to_datetime(Data_df['resolution_action_updated_date']).dt.strftime('%Y%m%d%H%M%S')
Data_df.head(35)
# Out:
#     unique_key        created_date agency  \
# 0     60887125 2024-04-17 02:11:06    DOT
# 2     60883318 2024-04-17 01:51:32   NYPD
# 3     60886001 2024-04-17 01:51:00   NYPD
# 4     60886141 2024-04-17 01:50:53    DHS
# 5     60889980 2024-04-17 01:50:38   NYPD
# 6     60890122 2024-04-17 01:50:05   NYPD
# 7     60886037 2024-04-17 01:50:03   NYPD
# 8     60887426 2024-04-17 01:47:04   NYPD
# 9     60886035 2024-04-17 01:46:39   NYPD
# 10    60883280 2024-04-17 01:46:21   NYPD
# 11    60891536 2024-04-17 01:44:37   NYPD
# 12    60884706 2024-04-17 01:44:01   NYPD
# 13    60885889 2024-04-17 01:43:45  DOHMH
# 14    60884700 2024-04-17 01:43:30   NYPD
# 15    60891803 2024-04-17 01:41:34   DSNY
# 16    60884699 2024-04-17 01:40:11   NYPD
# 17    60892935 2024-04-17 01:40:04   NYPD
# 18    60891534 2024-04-17 01:39:15   NYPD
# 19    60888801 2024-04-17 01:38:42   NYPD
# 20    60884695 2024-04-17 01:38:32   NYPD
# 21    60885361 2024-04-17 01:38:29   NYPD
# 22    60891364 2024-04-17 01:38:16   NYPD
# 23    60886042 2024-04-17 01:37:56   NYPD
# 24    60884679 2024-04-17 01:37:32   NYPD
# 25    60890170 2024-04-17 01:35:45   NYPD
# 26    60886002 2024-04-17 01:35:34   NYPD
# 27    60891767 2024-04-17 01:34:44   DSNY
# 28    60885449 2024-04-17 01:34:36   NYPD
# 29    60884529 2024-04-17 01:34:24  DOHMH
# 30    60893115 2024-04-17 01:34:08   DSNY
# 31    60885498 2024-04-17 01:33:56   NYPD
# 32    60887432 2024-04-17 01:33:34   NYPD
# 33    60892215 2024-04-17 01:33:18   NYPD
# 34    60890169 2024-04-17 01:33:02   NYPD
# 35    60888794 2024-04-17 01:32:24   NYPD
#
#                                 agency_name  \
# 0              Department of Transportation
# 2           New York City Police Department
# 3           New York City Police Department
# 4           Department of Homeless Services
# 5           New York City Police Department
# 6           New York City Police Department
# 7           New York City Police Department
# 8           New York City Police Department
# 9           New York City Police Department
# 10          New York City Police Department
# 11          New York City Police Department
# 12          New York City Police Department
# 13  Department of Health and Mental Hygiene
# 14          New York City Police Department
# 15                 Department of Sanitation
# 16          New York City Police Department
# 17          New York City Police Department
# 18          New York City Police Department
# 19          New York City Police Department
# 20          New York City Police Department
# 21          New York City Police Department
# 22          New York City Police Department
# 23          New York City Police Department
# 24          New York City Police Department
# 25          New York City Police Department
# 26          New York City Police Department
# 27                 Department of Sanitation
# 28          New York City Police Department
# 29  Department of Health and Mental Hygiene
# 30                 Department of Sanitation
# 31          New York City Police Department
# 32          New York City Police Department
# 33          New York City Police Department
# 34          New York City Police Department
# 35          New York City Police Department
#
#                             complaint_type                        descriptor  \
# 0                         Street Condition                           Pothole
# 2                      Noise - Residential                      Loud Talking
# 3                          Illegal Parking     Posted Parking Sign Violation
# 4               Homeless Person Assistance                           Chronic
# 5                         Blocked Driveway                         No Access
# 6                          Illegal Parking     Posted Parking Sign Violation
# 7                  Noise - Street/Sidewalk                  Loud Music/Party
# 8                      Noise - Residential                  Banging/Pounding
# 9                      Noise - Residential                  Loud Music/Party
# 10                         Illegal Parking                  Blocked Sidewalk
# 11                         Noise - Vehicle                     Engine Idling
# 12                 Noise - Street/Sidewalk                  Loud Music/Party
# 13                      Indoor Air Quality       Chemical Vapors/Gases/Odors
# 14                     Noise - Residential                  Loud Music/Party
# 15                           Lot Condition                             Trash
# 16                     Noise - Residential                  Loud Music/Party
# 17                         Noise - Vehicle                     Engine Idling
# 18                     Noise - Residential                  Loud Music/Party
# 19                     Noise - Residential                  Loud Music/Party
# 20                     Noise - Residential                  Banging/Pounding
# 21                     Noise - Residential                  Banging/Pounding
# 22                        Blocked Driveway                         No Access
# 23                 Noise - Street/Sidewalk                      Loud Talking
# 24                      Noise - Commercial                  Loud Music/Party
# 25                     Noise - Residential                  Loud Music/Party
# 26                         Illegal Parking     Posted Parking Sign Violation
# 27                      Vendor Enforcement                       Food Vendor
# 28                     Noise - Residential                      Loud Talking
# 29                          Drinking Water  Illness Caused by Drinking Water
# 30  Sanitation Worker or Vehicle Complaint                             Noise
# 31                 Noise - Street/Sidewalk                      Loud Talking
# 32                     Noise - Residential                      Loud Talking
# 33                      Noise - Commercial                  Loud Music/Party
# 34                     Noise - Residential                  Loud Music/Party
# 35                            Noise - Park                  Loud Music/Party
#
#     incident_zip           incident_address          street_name  \
# 0          11356                   7 AVENUE             7 AVENUE
# 2          11236      1570 EAST  102 STREET     EAST  102 STREET
# 3          11367    67-45 KISSENA BOULEVARD    KISSENA BOULEVARD
# 4          10019         200 WEST 52 STREET       WEST 52 STREET
# 5          11379            57-59 78 STREET            78 STREET
# 6          11365           162-05 71 AVENUE            71 AVENUE
# 7          10009       426 EAST   14 STREET     EAST   14 STREET
# 8          10460   1230 EAST TREMONT AVENUE  EAST TREMONT AVENUE
# 9          10454           400 BROOK AVENUE         BROOK AVENUE
# 10         11219                  40 STREET            40 STREET
# 11         11375                    67 ROAD              67 ROAD
# 12         10026        21 WEST  112 STREET     WEST  112 STREET
# 13         10002         20 CONFUCIUS PLAZA      CONFUCIUS PLAZA
# 14         11434          153-19 124 AVENUE           124 AVENUE
# 15         11221              HOWARD AVENUE        HOWARD AVENUE
# 16         10455         534 JACKSON AVENUE       JACKSON AVENUE
# 17         11223      1819 WEST    6 STREET     WEST    6 STREET
# 18         10452          1133 OGDEN AVENUE         OGDEN AVENUE
# 19         10452          1133 OGDEN AVENUE         OGDEN AVENUE
# 20         10456       266 EAST  165 STREET     EAST  165 STREET
# 21         11217          346 BERGEN STREET        BERGEN STREET
# 22         10023           AMSTERDAM AVENUE     AMSTERDAM AVENUE
# 23         11249           1 NORTHSIDE PIER       NORTHSIDE PIER
# 24         11361       40-12 BELL BOULEVARD       BELL BOULEVARD
# 25         11356        3-34 SOUNDVIEW LANE       SOUNDVIEW LANE
# 26         11385        66-32 MYRTLE AVENUE        MYRTLE AVENUE
# 27         10038               1 PACE PLAZA           PACE PLAZA
# 28         10456     1465 WASHINGTON AVENUE    WASHINGTON AVENUE
# 29         10025      1050 AMSTERDAM AVENUE     AMSTERDAM AVENUE
# 30         10280       345 SOUTH END AVENUE     SOUTH END AVENUE
# 31         10453         2270 WALTON AVENUE        WALTON AVENUE
# 32         11691  14-80 BEACH CHANNEL DRIVE  BEACH CHANNEL DRIVE
# 33         10463       240 WEST  231 STREET     WEST  231 STREET
# 34         10009       465 EAST   10 STREET     EAST   10 STREET
# 35         11220         6701 COLONIAL ROAD        COLONIAL ROAD
#
#                cross_street_1        cross_street_2  address_type  \
# 0                  122 STREET            123 STREET     BLOCKFACE
# 2              SEAVIEW AVENUE         SHORE PARKWAY       ADDRESS
# 3                   65 AVENUE      MELBOURNE AVENUE       ADDRESS
# 4                    7 AVENUE              BROADWAY       ADDRESS
# 5   QUEENS MIDTOWN EXPRESSWAY               57 ROAD       ADDRESS
# 6                  162 STREET            163 STREET       ADDRESS
# 7                    1 AVENUE              AVENUE A       ADDRESS
# 8         BRONX RIVER PARKWAY       VAN NEST AVENUE       ADDRESS
# 9            EAST  143 STREET      EAST  144 STREET       ADDRESS
# 10                  40 STREET    NEW UTRECHT AVENUE  INTERSECTION
# 11                    67 ROAD      QUEENS BOULEVARD  INTERSECTION
# 12                   5 AVENUE          LENOX AVENUE       ADDRESS
# 13                     BOWERY         MARKET STREET       ADDRESS
# 14                 153 STREET            155 STREET       ADDRESS
# 15              HOWARD AVENUE        MADISON STREET  INTERSECTION
# 16           EAST  147 STREET      EAST  149 STREET       ADDRESS
# 17            HIGHLAWN AVENUE              AVENUE S       ADDRESS
# 18           WEST  166 STREET      WEST  167 STREET       ADDRESS
# 19           WEST  166 STREET      WEST  167 STREET       ADDRESS
# 20               GRANT AVENUE         MORRIS AVENUE       ADDRESS
# 21                   3 AVENUE              4 AVENUE       ADDRESS
# 22           AMSTERDAM AVENUE      WEST   60 STREET  INTERSECTION
# 23                        NaN           KENT AVENUE       ADDRESS
# 24                  40 AVENUE             41 AVENUE       ADDRESS
# 25              PARK CRESCENT         PARK CRESCENT       ADDRESS
# 26                   66 PLACE              66 PLACE       ADDRESS
# 27              SPRUCE STREET      FRANKFORT STREET       ADDRESS
# 28             ST PAULS PLACE      EAST  171 STREET       ADDRESS
# 29           WEST  111 STREET      WEST  112 STREET       ADDRESS
# 30              ALBANY STREET        LIBERTY STREET       ADDRESS
# 31           EAST  182 STREET      EAST  183 STREET       ADDRESS
# 32             HASSOCK STREET  NASSAU CNTY BOUNDARY       ADDRESS
# 33             GODWIN TERRACE    KINGSBRIDGE AVENUE       ADDRESS
# 34                       BEND                   NaN       ADDRESS
# 35                  67 STREET        SENATOR STREET       ADDRESS
#
#               city       status resolution_action_updated_date  \
# 0           QUEENS         Open            2024-04-17 02:11:06
# 2         BROOKLYN  In Progress            2024-04-17 02:48:04
# 3         FLUSHING  In Progress                            NaT
# 4         NEW YORK     Assigned            2024-04-17 01:52:22
# 5   MIDDLE VILLAGE  In Progress                            NaT
# 6    FRESH MEADOWS  In Progress                            NaT
# 7         NEW YORK  In Progress                            NaT
# 8            BRONX  In Progress                            NaT
# 9            BRONX  In Progress            2024-04-17 02:38:37
# 10             NaN  In Progress            2024-04-17 02:39:09
# 11             NaN  In Progress            2024-04-17 01:57:21
# 12        NEW YORK  In Progress            2024-04-17 02:44:11
# 13        NEW YORK  In Progress                            NaT
# 14         JAMAICA  In Progress            2024-04-17 02:10:51
# 15             NaN  In Progress                            NaT
# 16           BRONX  In Progress            2024-04-17 02:18:45
# 17        BROOKLYN  In Progress            2024-04-17 02:25:07
# 18           BRONX  In Progress                            NaT
# 19           BRONX  In Progress                            NaT
# 20           BRONX  In Progress                            NaT
# 21        BROOKLYN       Closed            2024-04-17 01:43:57
# 22             NaN  In Progress            2024-04-17 02:06:45
# 23        BROOKLYN  In Progress            2024-04-17 02:28:48
# 24         BAYSIDE  In Progress            2024-04-17 02:23:52
# 25   COLLEGE POINT  In Progress            2024-04-17 02:31:05
# 26       RIDGEWOOD  In Progress                            NaT
# 27        NEW YORK  In Progress                            NaT
# 28           BRONX       Closed            2024-04-17 01:45:17
# 29        NEW YORK  In Progress                            NaT
# 30        NEW YORK  In Progress                            NaT
# 31           BRONX       Closed            2024-04-17 01:48:33
# 32    FAR ROCKAWAY  In Progress            2024-04-17 02:18:15
# 33           BRONX       Closed            2024-04-17 01:44:02
# 34        NEW YORK  In Progress            2024-04-17 02:08:05
# 35        BROOKLYN  In Progress            2024-04-17 02:11:42
#
#    community_board    borough open_data_channel_type park_facility_name  \
# 0        07 QUEENS     QUEENS                UNKNOWN        Unspecified
# 2      18 BROOKLYN   BROOKLYN                  PHONE        Unspecified
# 3        08 QUEENS     QUEENS                 MOBILE        Unspecified
# 4     05 MANHATTAN  MANHATTAN                 MOBILE        Unspecified
# 5        05 QUEENS     QUEENS                 ONLINE        Unspecified
# 6        08 QUEENS     QUEENS                 MOBILE        Unspecified
# 7     03 MANHATTAN  MANHATTAN                  PHONE        Unspecified
# 8         09 BRONX      BRONX                 MOBILE        Unspecified
# 9         01 BRONX      BRONX                  PHONE        Unspecified
# 10     12 BROOKLYN   BROOKLYN                 MOBILE        Unspecified
# 11       06 QUEENS     QUEENS                  PHONE        Unspecified
# 12    10 MANHATTAN  MANHATTAN                  PHONE        Unspecified
# 13    03 MANHATTAN  MANHATTAN                 ONLINE        Unspecified
# 14       12 QUEENS     QUEENS                  PHONE        Unspecified
# 15     03 BROOKLYN   BROOKLYN                  PHONE        Unspecified
# 16        01 BRONX      BRONX                 ONLINE        Unspecified
# 17     11 BROOKLYN   BROOKLYN                  PHONE        Unspecified
# 18        04 BRONX      BRONX                  PHONE        Unspecified
# 19        04 BRONX      BRONX                 ONLINE        Unspecified
# 20        04 BRONX      BRONX                  PHONE        Unspecified
# 21     02 BROOKLYN   BROOKLYN                  PHONE        Unspecified
# 22    07 MANHATTAN  MANHATTAN                  PHONE        Unspecified
# 23     01 BROOKLYN   BROOKLYN                  PHONE        Unspecified
# 24       11 QUEENS     QUEENS                 ONLINE        Unspecified
# 25       07 QUEENS     QUEENS                 ONLINE        Unspecified
# 26       05 QUEENS     QUEENS                 ONLINE        Unspecified
# 27    01 MANHATTAN  MANHATTAN                 ONLINE        Unspecified
# 28        03 BRONX      BRONX                 ONLINE        Unspecified
# 29    09 MANHATTAN  MANHATTAN                 ONLINE        Unspecified
# 30    01 MANHATTAN  MANHATTAN                 ONLINE        Unspecified
# 31        05 BRONX      BRONX                 MOBILE        Unspecified
# 32       14 QUEENS     QUEENS                  PHONE        Unspecified
# 33        08 BRONX      BRONX                  PHONE        Unspecified
# 34    03 MANHATTAN  MANHATTAN                  PHONE        Unspecified
# 35     10 BROOKLYN   BROOKLYN                 ONLINE        Unspecified
#
#    park_borough                 location_type   latitude  longitude  \
# 0        QUEENS                           NaN        NaN        NaN
# 2      BROOKLYN    Residential Building/House  40.634917 -73.884576
# 3        QUEENS               Street/Sidewalk  40.734313 -73.814760
# 4     MANHATTAN               Street/Sidewalk  40.762389 -73.982485
# 5        QUEENS               Street/Sidewalk  40.727503 -73.883420
# 6        QUEENS               Street/Sidewalk  40.730433 -73.806956
# 7     MANHATTAN               Street/Sidewalk  40.730862 -73.981360
# 8         BRONX    Residential Building/House  40.839721 -73.872316
# 9         BRONX    Residential Building/House  40.811543 -73.916891
# 10     BROOKLYN               Street/Sidewalk  40.644535 -73.994267
# 11       QUEENS               Street/Sidewalk  40.726570 -73.852639
# 12    MANHATTAN               Street/Sidewalk  40.798524 -73.949240
# 13    MANHATTAN  3+ Family Apartment Building  40.714151 -73.995942
# 14       QUEENS    Residential Building/House  40.675713 -73.787953
# 15     BROOKLYN                           Lot  40.688115 -73.921033
# 16        BRONX    Residential Building/House  40.812619 -73.909285
# 17     BROOKLYN               Street/Sidewalk  40.602881 -73.978706
# 18        BRONX    Residential Building/House  40.836319 -73.927477
# 19        BRONX    Residential Building/House  40.836319 -73.927477
# 20        BRONX    Residential Building/House  40.829362 -73.916601
# 21     BROOKLYN    Residential Building/House  40.682823 -73.980487
# 22    MANHATTAN               Street/Sidewalk  40.771055 -73.987144
# 23     BROOKLYN               Street/Sidewalk  40.719221 -73.964188
# 24       QUEENS           Club/Bar/Restaurant  40.764106 -73.771253
# 25       QUEENS    Residential Building/House  40.793956 -73.847875
# 26       QUEENS               Street/Sidewalk  40.701412 -73.887130
# 27    MANHATTAN                        Street  40.711908 -74.005843
# 28        BRONX    Residential Building/House  40.836941 -73.903744
# 29    MANHATTAN  3+ Family Apartment Building  40.804096 -73.963052
# 30    MANHATTAN                        Street  40.710796 -74.016105
# 31        BRONX               Street/Sidewalk  40.857841 -73.903103
# 32       QUEENS    Residential Building/House  40.610156 -73.753542
# 33        BRONX           Club/Bar/Restaurant  40.879623 -73.906225
# 34    MANHATTAN    Residential Building/House  40.724570 -73.974143
# 35     BROOKLYN               Park/Playground  40.639591 -74.030332
#
#         intersection_street_1 intersection_street_2         closed_date  \
# 0                         NaN                   NaN                 NaT
# 2              SEAVIEW AVENUE         SHORE PARKWAY                 NaT
# 3                   65 AVENUE      MELBOURNE AVENUE                 NaT
# 4                    7 AVENUE              BROADWAY                 NaT
# 5   QUEENS MIDTOWN EXPRESSWAY               57 ROAD                 NaT
# 6                  162 STREET            163 STREET                 NaT
# 7                    1 AVENUE              AVENUE A                 NaT
# 8         BRONX RIVER PARKWAY       VAN NEST AVENUE                 NaT
# 9            EAST  143 STREET      EAST  144 STREET                 NaT
# 10                  40 STREET    NEW UTRECHT AVENUE                 NaT
# 11                    67 ROAD      QUEENS BOULEVARD                 NaT
# 12                   5 AVENUE          LENOX AVENUE                 NaT
# 13                     BOWERY         MARKET STREET                 NaT
# 14                 153 STREET            155 STREET                 NaT
# 15              HOWARD AVENUE        MADISON STREET                 NaT
# 16           EAST  147 STREET      EAST  149 STREET                 NaT
# 17            HIGHLAWN AVENUE              AVENUE S                 NaT
# 18           WEST  166 STREET      WEST  167 STREET                 NaT
# 19           WEST  166 STREET      WEST  167 STREET                 NaT
# 20               GRANT AVENUE         MORRIS AVENUE                 NaT
# 21                   3 AVENUE              4 AVENUE 2024-04-17 01:43:53
# 22           AMSTERDAM AVENUE      WEST   60 STREET                 NaT
# 23                        NaN           KENT AVENUE                 NaT
# 24                  40 AVENUE             41 AVENUE                 NaT
# 25              PARK CRESCENT         PARK CRESCENT                 NaT
# 26                   66 PLACE              66 PLACE                 NaT
# 27              SPRUCE STREET      FRANKFORT STREET                 NaT
# 28             ST PAULS PLACE      EAST  171 STREET 2024-04-17 01:45:12
# 29           WEST  111 STREET      WEST  112 STREET                 NaT
# 30              ALBANY STREET        LIBERTY STREET                 NaT
# 31           EAST  182 STREET      EAST  183 STREET 2024-04-17 01:48:28
# 32             HASSOCK STREET  NASSAU CNTY BOUNDARY                 NaT
# 33             GODWIN TERRACE    KINGSBRIDGE AVENUE 2024-04-17 01:43:58
# 34                       BEND                   NaN                 NaT
# 35                  67 STREET        SENATOR STREET                 NaT
#
#    due_date  agencyType_id  locationType_id  location_id  complaintType_id  \
# 0       NaT              1                1         6555                 1
# 2       NaT              2                2            2                 2
# 3       NaT              2                3            3                 3
# 4       NaT              3                3            4                 4
# 5       NaT              2                3            5                 5
# 6       NaT              2                3            6                 3
# 7       NaT              2                3            7                 6
# 8       NaT              2                2            8                 2
# 9       NaT              2                2            9                 2
# 10      NaT              2                3           10                 3
# 11      NaT              2                3           11                 7
# 12      NaT              2                3           12                 6
# 13      NaT              4                4           13                 8
# 14      NaT              2                2           14                 2
# 15      NaT              5                5           15                 9
# 16      NaT              2                2           16                 2
# 17      NaT              2                3           17                 7
# 18      NaT              2                2           18                 2
# 19      NaT              2                2           18                 2
# 20      NaT              2                2           19                 2
# 21      NaT              2                2           20                 2
# 22      NaT              2                3           21                 5
# 23      NaT              2                3           22                 6
# 24      NaT              2                6           23                10
# 25      NaT              2                2           24                 2
# 26      NaT              2                3           25                 3
# 27      NaT              5                7           26                11
# 28      NaT              2                2         5382                 2
# 29      NaT              4                4           28                12
# 30      NaT              5                7           29                13
# 31      NaT              2                3           30                 6
# 32      NaT              2                2           31                 2
# 33      NaT              2                6           32                10
# 34      NaT              2                2           33                 2
# 35      NaT              2                8           34                14
#
#     statusType_id  park_facility_id  community_board_id  channel_id  \
# 0               1                 1                   1           1
# 2               2                 1                   2           2
# 3               2                 1                   3           3
# 4               3                 1                   4           3
# 5               2                 1                   5           4
# 6               2                 1                   3           3
# 7               2                 1                   6           2
# 8               2                 1                   7           3
# 9               2                 1                   8           2
# 10              2                 1                   9           3
# 11              2                 1                  10           2
# 12              2                 1                  11           2
# 13              2                 1                   6           4
# 14              2                 1                  12           2
# 15              2                 1                  13           2
# 16              2                 1                   8           4
# 17              2                 1                  14           2
# 18              2                 1                  15           2
# 19              2                 1                  15           4
# 20              2                 1                  15           2
# 21              4                 1                  16           2
# 22              2                 1                  17           2
# 23              2                 1                  18           2
# 24              2                 1                  19           4
# 25              2                 1                   1           4
# 26              2                 1                   5           4
# 27              2                 1                  20           4
# 28              4                 1                  21           4
# 29              2                 1                  22           4
# 30              2                 1                  20           4
# 31              4                 1                  23           3
# 32              2                 1                  24           2
# 33              4                 1                  25           2
# 34              2                 1                   6           2
# 35              2                 1                  26           4
#
#    created_date_id  closed_date_id due_date_id updated_date_id
# 0   20240417021106             NaN         NaN  20240417021106
# 2   20240417015132             NaN         NaN  20240417024804
# 3   20240417015100             NaN         NaN             NaN
# 4   20240417015053             NaN         NaN  20240417015222
# 5   20240417015038             NaN         NaN             NaN
# 6   20240417015005             NaN         NaN             NaN
# 7   20240417015003             NaN         NaN             NaN
# 8   20240417014704             NaN         NaN             NaN
# 9   20240417014639             NaN         NaN  20240417023837
# 10  20240417014621             NaN         NaN  20240417023909
# 11  20240417014437             NaN         NaN  20240417015721
# 12  20240417014401             NaN         NaN  20240417024411
# 13  20240417014345             NaN         NaN             NaN
# 14  20240417014330             NaN         NaN  20240417021051
# 15  20240417014134             NaN         NaN             NaN
# 16  20240417014011             NaN         NaN  20240417021845
# 17  20240417014004             NaN         NaN  20240417022507
# 18  20240417013915             NaN         NaN             NaN
# 19  20240417013842             NaN         NaN             NaN
# 20  20240417013832             NaN         NaN             NaN
# 21  20240417013829  20240417014353         NaN  20240417014357
# 22  20240417013816             NaN         NaN  20240417020645
# 23  20240417013756             NaN         NaN  20240417022848
# 24  20240417013732             NaN         NaN  20240417022352
# 25  20240417013545             NaN         NaN  20240417023105
# 26  20240417013534             NaN         NaN             NaN
# 27  20240417013444             NaN         NaN             NaN
# 28  20240417013436  20240417014512         NaN  20240417014517
# 29  20240417013424             NaN         NaN             NaN
# 30  20240417013408             NaN         NaN             NaN
# 31  20240417013356  20240417014828         NaN  20240417014833
# 32  20240417013334             NaN         NaN  20240417021815
# 33  20240417013318  20240417014358         NaN  20240417014402
# 34  20240417013302             NaN         NaN  20240417020805
# 35  20240417013224             NaN         NaN  20240417021142

# %%
mincreated_date = Data_df['created_date'].min()
minclosed_date = Data_df['closed_date'].min()
mindue_date = Data_df['due_date'].min()
minresolution_action_updated_date = Data_df['resolution_action_updated_date'].min()
print("Mincreated_date", mincreated_date,"\n",
      "minclosed_date",minclosed_date,"\n",
      "mindue_date", mindue_date,"\n",
      "minresolution_action_updated", minresolution_action_updated_date)



maxcreated_date = Data_df['created_date'].max()
maxclosed_date = Data_df['closed_date'].max()
maxdue_date = Data_df['due_date'].max()
maxresolution_action_updated_date = Data_df['resolution_action_updated_date'].max()
print("maxcreated_date", maxcreated_date,"\n",
      "maxclosed_date",maxclosed_date,"\n",
      "maxdue_date", maxdue_date,"\n",
      "maxresolution_action_updated", maxresolution_action_updated_date)
# Out:
# Mincreated_date 2024-04-16 04:31:55
#  minclosed_date 2024-03-19 14:34:00
#  mindue_date 2024-05-16 07:41:38
#  minresolution_action_updated 2024-01-03 10:50:08
# maxcreated_date 2024-04-17 02:11:06
#  maxclosed_date 2024-04-17 23:55:00
#  maxdue_date 2024-05-17 01:06:24
#  maxresolution_action_updated 2024-04-17 23:55:00

# %%
def week_of_month(dt):
    year = dt.year
    month =dt.month
    day= dt.day

    cal = calendar.monthcalendar(year,month)
    week_number = (day-1)//7+1
    return week_number

start_date = pd.to_datetime('2024-04-15')
end_date =  pd.to_datetime('2024-05-17')

date_dimension = pd.DataFrame({'date':pd.date_range(start_date, end_date, freq='S')})


date_dimension['year_number'] = date_dimension['date'].dt.year
date_dimension['month_number'] = date_dimension['date'].dt.month
date_dimension['monthName'] = date_dimension['date'].dt.strftime('%B')
date_dimension['day_number'] = date_dimension['date'].dt.day
date_dimension['dayName'] = date_dimension['date'].dt.strftime('%A')
date_dimension['hour_number'] = date_dimension['date'].dt.hour
date_dimension['minutes_number'] = date_dimension['date'].dt.minute
date_dimension['seconds_number'] = date_dimension['date'].dt.second
date_dimension['date_iso_format'] = date_dimension['date'].apply(lambda x: x.isoformat())
date_dimension['date_id'] = date_dimension['date'].dt.strftime('%Y%m%d%H%M%S')
date_dimension['weekOfMonth'] = date_dimension['date'].apply(week_of_month)
date_dimension['weekOfYear'] = date_dimension['date'].dt.strftime('%U')

# %%
new_order = ['date_id','year_number','month_number','monthName','day_number','dayName','hour_number','minutes_number','seconds_number','date_iso_format','weekOfMonth','weekOfYear']
date_dimension = date_dimension[new_order]
date_dimension.head(25)

# %%
# Calculate lead times and handle NaN or NaT values
Data_df['created_to_closed_lead_time'] = Data_df['closed_date'].sub(Data_df['created_date']).replace({pd.NaT: np.nan}).abs()
Data_df['due_date_to_closed_lead_time'] = Data_df['closed_date'].sub(Data_df['due_date']).replace({pd.NaT: np.nan}).abs()
Data_df['created_to_updated_lead_time'] = Data_df['created_date'].sub(Data_df['resolution_action_updated_date']).replace({pd.NaT: np.nan}).abs()
Data_df['created_to_due_date_lead_time'] = Data_df['created_date'].sub(Data_df['due_date']).replace({pd.NaT: np.nan}).abs()
Data_df['updated_to_closed_lead_time'] = Data_df['resolution_action_updated_date'].sub(Data_df['closed_date']).replace({pd.NaT: np.nan}).abs()
Data_df['updated_to_due_date_lead_time'] = Data_df['resolution_action_updated_date'].sub(Data_df['due_date']).replace({pd.NaT: np.nan}).abs()


Data_df.head(25)

# %%
# Convert timedelta to seconds
Data_df['created_to_closed_lead_time'] = Data_df['created_to_closed_lead_time'].dt.total_seconds()
Data_df['due_date_to_closed_lead_time'] = Data_df['due_date_to_closed_lead_time'].dt.total_seconds()
Data_df['created_to_updated_lead_time'] = Data_df['created_to_updated_lead_time'].dt.total_seconds()
Data_df['created_to_due_date_lead_time'] = Data_df['created_to_due_date_lead_time'].dt.total_seconds()
Data_df['updated_to_closed_lead_time'] = Data_df['updated_to_closed_lead_time'].dt.total_seconds()
Data_df['updated_to_due_date_lead_time'] = Data_df['updated_to_due_date_lead_time'].dt.total_seconds()


Data_df.head(50)

# %%
DataBefore = Data_df.copy()

new_col_names = {
    "location_id": "location_id",
    "locationType_id": "locationType_id",
    "complaintType_id": "complaintType_id",
    "agencyType_id":"agencyType_id",
    "community_board_id": "community_board_id",
    "park_facility_id":"park_facility_id",
    "channel_id": "channel_id",
    "statusType_id": "statusType_id",
    "created_date_id": "created_date_id",
    "closed_date_id": "closed_date_id",
    "due_date_id": "due_date_id",
    "updated_date_id": "updated_date_id",
    "created_to_closed_lead_time": "created_to_closed_lead_time",
    "due_date_to_closed_lead_time":"due_date_to_closed_lead_time",
    "created_to_updated_lead_time" :"created_to_updated_lead_time",
    "created_to_due_date_lead_time":"created_to_due_date_lead_time",
    "updated_to_closed_lead_time":"updated_to_closed_lead_time",
    "updated_to_due_date_lead_time":"updated_to_due_date_lead_time"

}

Data_df = Data_df.rename(columns=new_col_names)
Data_df["fact_id"] = range(1, len(Data_df) + 1)

new_order = ["fact_id",
             "location_id",
             "locationType_id",
             "complaintType_id",
             "agencyType_id",
             "community_board_id",
             "channel_id",
             "statusType_id",
             "created_date_id",
             "closed_date_id",
             "due_date_id",
             "updated_date_id",
             "created_to_closed_lead_time",
             "due_date_to_closed_lead_time",
             "created_to_updated_lead_time" ,
             "created_to_due_date_lead_time",
             "updated_to_closed_lead_time",
             "updated_to_due_date_lead_time"]

Fact_Table = Data_df[new_order]
Fact_Table.to_csv('Fact_Table.csv', index=False)
# Display the DataFrame
Fact_Table.head(25)

# %%
# Load Azure Storage connection string and container name from config.json
with open('config.json', 'r') as f:
    config = json.load(f)

connection_string = config['connectionString']


# Path to your local CSV file
container_name = 'data'
file_path = "Fact_Table.csv"
blob_name = "311FactTable"

# Create a blob service client
blob_service_client = BlobServiceClient.from_connection_string(connection_string)

# Create a blob client using the container and blob name
blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)

# Upload the file
with open(file_path, "rb") as data:
    blob_client.upload_blob(data)

# %%
#importing azure
# !pip install azure-storage-blob
from azure.storage.blob import BlobServiceClient, ContainerClient
# Out:
# Requirement already satisfied: azure-storage-blob in /opt/anaconda3/lib/python3.9/site-packages (12.19.1)
# Requirement already satisfied: isodate>=0.6.1 in /opt/anaconda3/lib/python3.9/site-packages (from azure-storage-blob) (0.6.1)
# Requirement already satisfied: cryptography>=2.1.4 in /opt/anaconda3/lib/python3.9/site-packages (from azure-storage-blob) (37.0.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in /opt/anaconda3/lib/python3.9/site-packages (from azure-storage-blob) (1.30.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from azure-storage-blob) (4.10.0)
# Requirement already satisfied: requests>=2.21.0 in /opt/anaconda3/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.28.1)
# Requirement already satisfied: six>=1.11.0 in /opt/anaconda3/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.9/site-packages (from cryptography>=2.1.4->azure-storage-blob) (1.15.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.21)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.0.4)

# %%
#importing libraries
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import requests
import json
from io import StringIO
import os

# %%
#Api call 
url = "https://data.cityofnewyork.us/resource/erm2-nwe9.json?$limit=10000"
response = requests.get(url)
data = response.json()
#adding data to pd.dataframe, saving to csv
df = pd.json_normalize(data)
df.to_csv('311Data.csv', index=False)
print(df)
# Out:
#      unique_key             created_date agency  \
# 0      60810444  2024-04-09T02:28:57.000   DSNY
# 1      60804370  2024-04-09T02:28:00.000   DSNY
# 2      60810445  2024-04-09T02:26:41.000   DSNY
# 3      60811478  2024-04-09T02:24:47.000   DSNY
# 4      60809226  2024-04-09T02:23:26.000   DSNY
# ...         ...                      ...    ...
# 9995   60802725  2024-04-07T21:42:31.000   NYPD
# 9996   60799871  2024-04-07T21:42:19.000   NYPD
# 9997   60800452  2024-04-07T21:42:11.000   NYPD
# 9998   60800749  2024-04-07T21:42:05.000   NYPD
# 9999   60798992  2024-04-07T21:41:50.000   NYPD
#
#                           agency_name           complaint_type  \
# 0            Department of Sanitation                 Graffiti
# 1            Department of Sanitation                 Graffiti
# 2            Department of Sanitation                 Graffiti
# 3            Department of Sanitation                 Graffiti
# 4            Department of Sanitation                 Graffiti
# ...                               ...                      ...
# 9995  New York City Police Department  Noise - Street/Sidewalk
# 9996  New York City Police Department      Noise - Residential
# 9997  New York City Police Department          Illegal Parking
# 9998  New York City Police Department      Noise - Residential
# 9999  New York City Police Department  Noise - Street/Sidewalk
#
#             descriptor               location_type incident_zip  \
# 0             Graffiti                   Comercial        11234
# 1             Graffiti                   Comercial        11234
# 2             Graffiti                   Comercial        11234
# 3             Graffiti                   Mixed Use        11234
# 4             Graffiti                   Comercial        11216
# ...                ...                         ...          ...
# 9995  Loud Music/Party             Street/Sidewalk        10467
# 9996  Loud Music/Party  Residential Building/House        11378
# 9997   Blocked Hydrant             Street/Sidewalk        11374
# 9998  Banging/Pounding  Residential Building/House        10001
# 9999  Loud Music/Party             Street/Sidewalk        11355
#
#           incident_address       street_name  ... intersection_street_1  \
# 0         2102 MILL AVENUE       MILL AVENUE  ...                   NaN
# 1     2186 FLATBUSH AVENUE   FLATBUSH AVENUE  ...                   NaN
# 2     2118 FLATBUSH AVENUE   FLATBUSH AVENUE  ...                   NaN
# 3     2114 FLATBUSH AVENUE   FLATBUSH AVENUE  ...                   NaN
# 4       120 MADISON STREET    MADISON STREET  ...                   NaN
# ...                    ...               ...  ...                   ...
# 9995    3545 JEROME AVENUE     JEROME AVENUE  ...        UNNAMED STREET
# 9996        51-65 72 PLACE          72 PLACE  ...        CALAMUS AVENUE
# 9997        99-32 63 DRIVE          63 DRIVE  ...             99 STREET
# 9998  330 WEST   30 STREET  WEST   30 STREET  ...              8 AVENUE
# 9999      43 MERIDIAN ROAD     MERIDIAN ROAD  ...  AVENUE OF ENTERPRISE
#
#               intersection_street_2          landmark taxi_pick_up_location  \
# 0                               NaN               NaN                   NaN
# 1                               NaN               NaN                   NaN
# 2                               NaN               NaN                   NaN
# 3                               NaN               NaN                   NaN
# 4                               NaN               NaN                   NaN
# ...                             ...               ...                   ...
# 9995  MAJOR DEEGAN EXPWY NB ET   13     JEROME AVENUE                   NaN
# 9996                        53 ROAD          72 PLACE                   NaN
# 9997                     102 STREET          63 DRIVE                   NaN
# 9998                       9 AVENUE  WEST   30 STREET                   NaN
# 9999               PATH OF RESEARCH     MERIDIAN ROAD                   NaN
#
#      vehicle_type bridge_highway_name bridge_highway_direction  \
# 0             NaN                 NaN                      NaN
# 1             NaN                 NaN                      NaN
# 2             NaN                 NaN                      NaN
# 3             NaN                 NaN                      NaN
# 4             NaN                 NaN                      NaN
# ...           ...                 ...                      ...
# 9995          NaN                 NaN                      NaN
# 9996          NaN                 NaN                      NaN
# 9997          NaN                 NaN                      NaN
# 9998          NaN                 NaN                      NaN
# 9999          NaN                 NaN                      NaN
#
#      bridge_highway_segment road_ramp taxi_company_borough
# 0                       NaN       NaN                  NaN
# 1                       NaN       NaN                  NaN
# 2                       NaN       NaN                  NaN
# 3                       NaN       NaN                  NaN
# 4                       NaN       NaN                  NaN
# ...                     ...       ...                  ...
# 9995                    NaN       NaN                  NaN
# 9996                    NaN       NaN                  NaN
# 9997                    NaN       NaN                  NaN
# 9998                    NaN       NaN                  NaN
# 9999                    NaN       NaN                  NaN
#
# [10000 rows x 49 columns]

# %%
#printing summary information 
df.head()
print(df.info())
print(df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 49 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   unique_key                      10000 non-null  object
#  1   created_date                    10000 non-null  object
#  2   agency                          10000 non-null  object
#  3   agency_name                     10000 non-null  object
#  4   complaint_type                  10000 non-null  object
#  5   descriptor                      9995 non-null   object
#  6   location_type                   8747 non-null   object
#  7   incident_zip                    9919 non-null   object
#  8   incident_address                9649 non-null   object
#  9   street_name                     9648 non-null   object
#  10  address_type                    9961 non-null   object
#  11  city                            9548 non-null   object
#  12  facility_type                   809 non-null    object
#  13  status                          10000 non-null  object
#  14  resolution_description          7618 non-null   object
#  15  resolution_action_updated_date  7733 non-null   object
#  16  community_board                 10000 non-null  object
#  17  bbl                             8813 non-null   object
#  18  borough                         10000 non-null  object
#  19  x_coordinate_state_plane        9759 non-null   object
#  20  y_coordinate_state_plane        9759 non-null   object
#  21  open_data_channel_type          10000 non-null  object
#  22  park_facility_name              10000 non-null  object
#  23  park_borough                    10000 non-null  object
#  24  latitude                        9759 non-null   object
#  25  longitude                       9759 non-null   object
#  26  :@computed_region_efsh_h5xi     9720 non-null   object
#  27  :@computed_region_f5dn_yrer     9755 non-null   object
#  28  :@computed_region_yeji_bk3q     9755 non-null   object
#  29  :@computed_region_92fq_4b7q     9755 non-null   object
#  30  :@computed_region_sbqj_enih     9755 non-null   object
#  31  :@computed_region_7mpf_4k6g     9755 non-null   object
#  32  location.latitude               9759 non-null   object
#  33  location.longitude              9759 non-null   object
#  34  location.human_address          9759 non-null   object
#  35  due_date                        41 non-null     object
#  36  cross_street_1                  7326 non-null   object
#  37  cross_street_2                  7326 non-null   object
#  38  closed_date                     5405 non-null   object
#  39  intersection_street_1           6890 non-null   object
#  40  intersection_street_2           6892 non-null   object
#  41  landmark                        6221 non-null   object
#  42  taxi_pick_up_location           116 non-null    object
#  43  vehicle_type                    596 non-null    object
#  44  bridge_highway_name             50 non-null     object
#  45  bridge_highway_direction        32 non-null     object
#  46  bridge_highway_segment          50 non-null     object
#  47  road_ramp                       23 non-null     object
#  48  taxi_company_borough            2 non-null      object
# dtypes: object(49)
# memory usage: 3.7+ MB
# None
# (10000, 49)
